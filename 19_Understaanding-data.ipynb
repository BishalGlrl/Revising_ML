# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %% [markdown]
# # How big is data?

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # 1) HOW DATA LOOKS

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.sample(10) #This will give random 10 data
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 60            61         0       3         Sirayanian, Mr. Orsen    male
# 401          402         0       3               Adams, Mr. John    male
# 374          375         0       3    Palsson, Miss. Stina Viola  female
# 857          858         1       1        Daly, Mr. Peter Denis     male
# 668          669         0       3               Cook, Mr. Jacob    male
# 174          175         0       1       Smith, Mr. James Clinch    male
# 382          383         0       3            Tikkanen, Mr. Juho    male
# 824          825         0       3  Panula, Master. Urho Abraham    male
# 64            65         0       1         Stewart, Mr. Albert A    male
# 257          258         1       1          Cherry, Miss. Gladys  female
#
#       Age  SibSp  Parch             Ticket     Fare Cabin Embarked
# 60   22.0      0      0               2669   7.2292   NaN        C
# ...

# %% [markdown]
# # 3.What is the type of column

# %%
df.info() #It gives the datatype of the column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # 4. ARE THERE ANY MISSING VALUE

# %%
df.isnull().sum() #This shows the number of missing value in each column
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # HOW DOES DATA LOOKS MATHEMATICALLY

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Are there duplicate values(Row)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # How is the correlation between columns(How are column related to each other)

# %%
df = df.drop('Name',axis = 1) #TO delete the column

# %%
df.columns
#It gives correlatiion in between 1 and -1.So if the correlation is said to be positive then they are inversely correlated.If it is negative
#they are correlated
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
columns_to_delete = ['Sex','Ticket','Cabin','Embarked']

# %%
df = df.drop(columns=columns_to_delete,axis = 1)

# %%
df.corr() #This only works when you have numeric data in columns
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df.corr()['Survived']
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64
